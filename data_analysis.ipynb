# %%
# %matplotlib widget
import re
import json
import tqdm
import queue
import urllib
from nltk.tokenize import word_tokenize
from collections import defaultdict
import networkx as nx
import time
import socks
import socket
import pickle
import matplotlib.pyplot as plt
from multiprocessing.pool import ThreadPool as Pool

# %%
socks.set_default_proxy(socks.SOCKS5, "localhost", 10087)
socket.socket = socks.socksocket

# %%
def instance2dict(instance):
	# convert the instance into a dict
    tmp_dict = {}
    tmp_dict['question'] = instance[0].split('\t')[1].strip()
    logical_form_rexpr_pattern = r"[\(] [r\-]*mso:([\w\.]*) (([\?][xy])|[\S]+) (([\?][xy])|[\S]+) [\)]"
    entity_rexpr_pattern = r"([\S]+) \(entity\)" # r"([\S]+) (?:\(entity\)|\(value\)|\(type\)) \[([\d]+,[\d]+)\]"
    
    logical_form = instance[1].split('\t')[1].strip()
    tmp_dict['logical_form'] = re.findall(logical_form_rexpr_pattern, logical_form)
    
    tmp_dict['parameters'] = re.findall(entity_rexpr_pattern, instance[2].split('\t')[1].strip())
    tmp_dict['question_type'] = instance[3].split('\t')[1].strip()
    return tmp_dict

def fetch_data(file):
	# fetch data from the original file
	lines = file.readlines()
	instance_list = []
	tmp_instance = []
	for line in lines:
		if line.strip()=="==================================================":
			instance_list.append(instance2dict(tmp_instance))
			tmp_instance = []
		else:
			tmp_instance.append(line)
	return instance_list

# %% [raw]
# def instance2dict(instance):
# 	# convert the instance into a dict
#     tmp_dict = {}
#     tmp_dict['question'] = word_tokenize(" ".join(instance[0].split('\t')[1].strip().split()))
#
#     logical_form_rexpr_pattern = r"[\(] [r\-]*mso:([\w\.]*) (([\?][xy])|[\S]+) (([\?][xy])|[\S]+) [\)]"
#     entity_rexpr_pattern = r"([\S]+) (?:\(entity\)|\(value\)|\(type\)) \[([\d]+,[\d]+)\]"
#
#     logical_form = instance[1].split('\t')[1].strip()
#     try:
#         tmp_dict['logical_form'] = re.findall(logical_form_rexpr_pattern, logical_form)[0]
#     except:
#         tmp_dict['logical_form'] = None
#
#     try:
#         tmp_dict['parameters'] = re.findall(entity_rexpr_pattern, instance[2].split('\t')[1].strip())[0][0]
#     except:
#         print(instance)
#
#
#     tmp_dict['parameters_surface'] = instance[0].split('\t')[1].strip().split()[slice(*eval("("+re.findall(entity_rexpr_pattern, instance[2].split('\t')[1].strip())[0][1]+")"))]
#     tmp_dict['parameters_surface'] = word_tokenize(" ".join(tmp_dict['parameters_surface']))
#
#     tmp_dict['question_type'] = instance[3].split('\t')[1].strip()
#     return tmp_dict

# %%
dev_file = open("DATA/EMNLP.dev", 'r', encoding='utf-8')
train_file = open("DATA/EMNLP.train", 'r', encoding='utf-8')
test_file = open("DATA/EMNLP.test", 'r', encoding='utf-8')
dev_data = fetch_data(dev_file)
train_data = fetch_data(train_file)
test_data = fetch_data(test_file)

# %%
def get_logical_forms(samples):
    all_logical_form_stats = defaultdict(int)
    for sample in samples:
        logical_forms = sample.get("logical_form")
        for logical_form in logical_forms:
            all_logical_form_stats[logical_form[0]] += 1
    return all_logical_form_stats

def get_entities(samples):
    all_entities = defaultdict(int)
    for sample in samples:
        entities = sample.get("parameters")
        for entitiy in entities:
            all_entities[entitiy[0]] += 1
    return all_entities

def get_category_tree(all_logical_form_stats):
    G_cat = nx.DiGraph()
    for x in train_logical_form_stats:
        x = x[4:]
        cats = x.split(".")
        parent_node = "root"
        for cat in cats:
            if "#" in cat:
                print(cat)
            cat = parent_node + "#" + cat
            G_cat.add_node(cat)
            G_cat.add_edge(parent_node, cat)
            parent_node = cat    
    return G_cat

# %%
dev_logical_form_stats = get_logical_forms(dev_data)
train_logical_form_stats = get_logical_forms(train_data)

dev_category_tree = get_category_tree(dev_logical_form_stats)
train_category_tree = get_category_tree(train_logical_form_stats)

shortest_path = dict(nx.all_pairs_shortest_path(dev_category_tree))

# %%
sorted(dev_logical_form_stats.items(), key=lambda x:-x[1])
# Out:
# [('book.author.works_written', 144),
#  ('baseball.player.batting_statistics', 57),
#  ('comic_books.creator.series', 48),
#  ('music.artist.album', 47),
#  ('time.event.start_date', 47),
#  ('tv.regular_tv_appearance.actor', 37),
#  ('location.sovereign.calling_code', 35),
#  ('baseball.batting_statistics.season', 34),
#  ('location.sovereign.official_language', 29),
#  ('film.film.writer', 28),
#  ('sports.pro_athlete.team', 28),
#  ('tv.character.appeared_in_tv_program', 28),
#  ('time.event.person', 26),
#  ('people.person.education', 26),
#  ('biology.domesticated_animal.breeds', 26),
#  ('book.written_work.date_of_first_publication', 25),
#  ('baseball.batting_statistics.team', 24),
#  ('sports.sports_team_roster.team', 24),
#  ('time.event.end_date', 22),
#  ('film.film.music', 21),
#  ('film.actor.film', 20),
#  ('organization.board_membership.organization', 19),
#  ('organization.board_member.leader_of', 19),
#  ('cvg.computer_videogame.developer', 19),
#  ('people.person.date_of_birth', 19),
#  ('sports.team.color', 19),
#  ('film.film.director', 19),
#  ('tv.program.episode_running_time', 18),
#  ('location.location.administrative_capital', 17),
#  ('people.person.marriage', 17),
#  ('geography.river.origin', 16),
#  ('film.film.soundtrack', 16),
#  ('organization.leadership.organization', 16),
#  ('award.nominee.award_nominations', 16),
#  ('film.film.art_director', 16),
#  ('film.film.rating', 16),
#  ('law.invention.inventor', 15),
#  ('geography.lake.inflow', 15),
#  ('sports.multi_event_tournament.competitor_competition_relationship', 15),
#  ('comic_books.publisher.comic_book_series_published', 15),
#  ('organization.board_membership.role', 15),
#  ('medicine.medical_treatment.used_to_treat', 15),
#  ('film.film.performance', 14),
#  ('film.performance.character', 14),
#  ('projects.project.project_participation', 14),
#  ('film.film.cinematographer', 14),
#  ('film.film.prequel', 14),
#  ('government.governmental_jurisdiction.governing_officials', 14),
#  ('sports.team.coach', 14),
#  ('cvg.computer_videogame.release_date', 14),
#  ('people.person.children', 14),
#  ('organization.leadership.role', 14),
#  ('cvg.game_version.developer', 14),
#  ('organization.organization.leadership', 13),
#  ('architecture.museum.established', 13),
#  ('geography.mountain.last_eruption', 13),
#  ('people.person.sexual_relationship', 13),
#  ('film.film.sequel', 13),
#  ('award.honor.year', 13),
#  ('theater.play.musical_soundtrack', 12),
#  ('education.education.educational_institution', 12),
#  ('people.deceased_person.place_of_burial', 12),
#  ('aviation.airliner_accident.aviation_incident_aircraft_relationship', 12),
#  ('architecture.building.floors', 12),
#  ('american_football.player.player_passing_statistics', 12),
#  ('sports.sports_team_coach_tenure.coach', 12),
#  ('american_football.team.division', 11),
#  ('business.employment_tenure.job_title', 11),
#  ('aviation.aviation_incident_aircraft_relationship.flight_destination', 11),
#  ('film.film.casting_director', 11),
#  ('tv.program.program_creator', 11),
#  ('organization.board_member.organization_board_membership', 11),
#  ('sports.championship_event.champion', 11),
#  ('education.education.educational_degree', 11),
#  ('sports.team.facility', 11),
#  ('tv.series_season.regular_cast', 11),
#  ('film.film.story', 11),
#  ('architecture.structure.style', 10),
#  ('projects.project_participation.project_participant', 10),
#  ('education.academic.advisors', 10),
#  ('location.location.area', 10),
#  ('geography.body_of_water.surface_area', 10),
#  ('american_football.player.position', 10),
#  ('government.position_held.office_or_title', 10),
#  ('music.track.length', 10),
#  ('architecture.museum.director', 10),
#  ('organization.leadership.person', 10),
#  ('sports.competitor_competition_relationship.competitor', 10),
#  ('american_football.player_passing_statistics.season', 10),
#  ('sports.sports_team_roster.position', 10),
#  ('film.performance.actor', 10),
#  ('military.person.service', 10),
#  ('soccer.player.senior_career_roster', 10),
#  ('tv.program.air_date_of_first_episode', 10),
#  ('chemistry.chemical_element.element_discoverer', 10),
#  ('sports.sports_team_coach_tenure.position', 10),
#  ('award.winner.awards_won', 10),
#  ('organization.board_membership.title', 10),
#  ('geography.lake.outflow', 9),
#  ('architecture.structure.destruction_date', 9),
#  ('sports.pro_athlete.career_end', 9),
#  ('comic_books.series.featured_characters', 9),
#  ('location.location.time_zone', 9),
#  ('organization.organization.date_founded', 9),
#  ('people.romantic_relationship.person', 9),
#  ('radio.radio_program.final_broadcast', 9),
#  ('chemistry.chemical_compound.formula', 9),
#  ('architecture.structure.firm', 9),
#  ('computer.computer.processor', 9),
#  ('time.event.location', 9),
#  ('astronomy.orbital_relationship.orbital_period', 9),
#  ('astronomy.celestial_object.mean_radius', 9),
#  ('organization.organization.board_members', 9),
#  ('location.dated_location.date_dissolved', 9),
#  ('tv.program.regular_cast', 9),
#  ('tv.regular_tv_appearance.special_tv_performance_type', 9),
#  ('business.board_member.organization_board_memberships', 9),
#  ('film.film.producer', 9),
#  ('people.deceased_person.preferred_cause_of_death', 9),
#  ('aviation.aircraft_model.introduced', 8),
#  ('military.unit.formed', 8),
#  ('people.person.business_employment_tenure', 8),
#  ('architecture.venue.capacity', 8),
#  ('aviation.aircraft_model.aircraft', 8),
#  ('book.written_work.synopsis', 8),
#  ('people.person.parent', 8),
#  ('martial_arts.martial_art.well_known_practitioner', 8),
#  ('sports.professional_sports_team.team_owner', 8),
#  ('soccer.team_management_tenure.from', 8),
#  ('sports.competitor_competition_relationship.medal', 8),
#  ('projects.project_participation.project_role', 8),
#  ('soccer.player.player_transfer', 8),
#  ('visual_art.art_period_movement.began_approximately', 8),
#  ('organization.organization.headquarters', 8),
#  ('location.location.legislative_capital', 8),
#  ('olympics.games.number_of_countries', 8),
#  ('geography.mountain.elevation', 8),
#  ('location.sovereign.iso4217_currency_code', 8),
#  ('food.food.energy', 8),
#  ('transportation.bridge.locale', 8),
#  ('geography.island.max_width', 8),
#  ('tv.program.theme_song', 8),
#  ('astronomy.celestial_object.absolute_magnitude', 8),
#  ('biology.organism.date_of_birth', 8),
#  ('tv.regular_tv_appearance.from', 8),
#  ('people.deceased_person.date_of_death', 8),
#  ('boats.ship.launched', 8),
#  ('biology.organism_classification.fossil_specimens', 8),
#  ('american_football.player.player_receiving_statistics', 8),
#  ('tv.regular_tv_appearance.program', 8),
#  ('chemistry.chemical_element.electron_configuration', 8),
#  ('visual_art.art_series.artwork', 8),
#  ('sports.team.team_season_record', 7),
#  ('sports.team_season_record.season', 7),
#  ('aviation.airliner_accident.date', 7),
#  ('organization.founder.organizations_founded', 7),
#  ('aviation.aviation_incident_aircraft_relationship.survivors', 7),
#  ('organization.leadership.title', 7),
#  ('theater.play.composer', 7),
#  ('book.periodical.editorial_staff', 7),
#  ('book.editorial_tenure.editor', 7),
#  ('people.person.quotation', 7),
#  ('astronomy.astronomical_discovery.discovery_date', 7),
#  ('sports.sports_team_roster.total_goals', 7),
#  ('business.employment_tenure.employer', 7),
#  ('geography.mountain_pass.transversed_by', 7),
#  ('education.educational_institution.color', 7),
#  ('astronomy.orbital_relationship.orbital_order', 7),
#  ('book.written_work.copyright_date', 7),
#  ('cvg.computer_videogame.designer', 7),
#  ('biology.fossil_specimen.found_at_site', 7),
#  ('american_football.player_passing_statistics.team', 7),
#  ('aviation.airliner_accident.fatality', 7),
#  ('book.written_work.original_language', 7),
#  ('soccer.match.player_match_participation', 7),
#  ('soccer.player_match_participation.player', 7),
#  ('book.literary_series.author', 7),
#  ('chemistry.chemical_element.melting_point', 7),
#  ('boats.ship_class.max_speed_knots', 7),
#  ('education.education.major', 7),
#  ('people.person.nationality_adjectival', 7),
#  ('geography.river.mouth', 7),
#  ('media_common.adapted_work.adaptations', 7),
#  ('education.educational_institution.school_mascot', 7),
#  ('biology.deceased_organism.date_of_death', 7),
#  ('biology.fossil_specimen.date_discovered', 7),
#  ('government.position_held.basic_title', 7),
#  ('government.position_held.office_holder', 7),
#  ('cvg.computer_videogame.publisher', 7),
#  ('media_common.creative_work.content_rating', 7),
#  ('government.position_held.district_represented', 7),
#  ('computer.software.first_released', 7),
#  ('book.written_work.author', 7),
#  ('chemistry.chemical_compound.classifications', 7),
#  ('book.written_work.previous_in_series', 7),
#  ('award.long_list_nomination.year', 7),
#  ('film.film.production_company', 7),
#  ('geography.lake.surface_elevation', 7),
#  ('chemistry.element_discoverer.discovered', 6),
#  ('government.politician.party', 6),
#  ('government.political_party_tenure.party', 6),
#  ('fictional_universe.character.parents', 6),
#  ('boats.ship.ship_designer', 6),
#  ('film.film.executive_producer', 6),
#  ('baseball.batting_statistics.games', 6),
#  ('projects.project_participation.from_date', 6),
#  ('visual_art.artwork.period_or_movement', 6),
#  ('soccer.team.manager', 6),
#  ('soccer.team_management_tenure.manager', 6),
#  ('spaceflight.rocket.manufacturer', 6),
#  ('meteorology.tropical_cyclone.total_fatalities', 6),
#  ('religion.founding_figure.religion_founded', 6),
#  ('religion.religious_organization.religious_organization_leadership', 6),
#  ('visual_art.artwork.date_begun', 6),
#  ('biology.organism_classification.max_speed', 6),
#  ('spaceflight.space_program.started', 6),
#  ('metropolitan_transit.transit_system.inception', 6),
#  ('organization.organization.spin_offs', 6),
#  ('organization.spin_off.child_company', 6),
#  ('organization.spin_off.date', 6),
#  ('music.composition.composer', 6),
#  ('protected_sites.protected_site.date_established', 6),
#  ('military.service.armed_force', 6),
#  ('soccer.player.loans', 6),
#  ('soccer.player_loan.borrowing_team', 6),
#  ('people.person.height', 6),
#  ('film.actor.performance', 6),
#  ('award.long_list_nomination.award', 6),
#  ('architecture.structure.architect', 6),
#  ('time.recurring_event.date_of_first_occurance', 6),
#  ('award.winning_work.honor', 6),
#  ('sports.team.previously_known_as', 6),
#  ('computer.programming_language_designer.languages_designed', 6),
#  ('sports.sports_team_roster.appearances', 6),
#  ('soccer.roster_position.team', 6),
#  ('computer.operating_system.release_date', 6),
#  ('education.fraternity_sorority.color', 6),
#  ('geography.lake.length', 6),
#  ('protected_sites.protected_site.governing_body_of_protected_sites', 6),
#  ('soccer.player_transfer.purchasing_team', 6),
#  ('chemistry.chemical_compound.average_molar_mass', 6),
#  ('travel.destination.climate', 6),
#  ('travel.destination_monthly_climate.month', 6),
#  ('architecture.structure.height_meters', 6),
#  ('sports.sports_team_roster.to', 6),
#  ('olympics.torchbearer.participation_in_relays', 6),
#  ('olympics.torch_relay.olympics', 6),
#  ('tv.network.former_names', 6),
#  ('music.opera_singer.voice_type', 6),
#  ('education.school_newspaper.school', 6),
#  ('american_football.player_receiving_statistics.team', 6),
#  ('astronomy.galaxy.constellation', 6),
#  ('zoos.zoo.closed', 6),
#  ('music.composition.lyricist', 6),
#  ('theater.play.lyricist', 6),
#  ('sports.team.founded', 6),
#  ('music.album.artist', 6),
#  ('baseball.team.team_stats', 6),
#  ('baseball.team_stats.season', 6),
#  ('award.honor.winner', 6),
#  ('visual_art.art_period_movement.ended_approximately', 6),
#  ('tv.regular_tv_appearance.to', 6),
#  ('zoos.zoo.notable_animal', 6),
#  ('zoos.animal_captivity.animal', 6),
#  ('music.album.release_date', 6),
#  ('tv.series_season.from', 6),
#  ('architecture.architect.structure', 6),
#  ('music.composition.musical_scale', 6),
#  ('baseball.batting_statistics.hit_by_pitch', 5),
#  ('amusement_parks.roller_coaster.track_length', 5),
#  ('boats.ship.displacement', 5),
#  ('transportation.road.major_cities', 5),
#  ('award.category.date_established', 5),
#  ('astronomy.celestial_object.surface_area', 5),
#  ('aviation.aircraft_model.manufacturer', 5),
#  ('martial_arts.martial_artist.martial_art', 5),
#  ('sports.team.mascot', 5),
#  ('government.political_appointer.appointees', 5),
#  ('olympics.host_city.olympics_hosted', 5),
#  ('music.composition.compositional_form', 5),
#  ('theater.play.orchestrator', 5),
#  ('cvg.game_version.release_date', 5),
#  ('sports.pro_athlete.sports_played_professionally', 5),
#  ('astronomy.asterism.constellation', 5),
#  ('american_football.player_passing_statistics.interceptions', 5),
#  ('chemistry.chemical_element.discovery_date', 5),
#  ('aviation.aircraft_model.maximum_speed_km_h', 5),
#  ('chemistry.chemical_element.atomic_number', 5),
#  ('film.film.tagline', 5),
#  ('music.album.length', 5),
#  ('education.education.minor', 5),
#  ('visual_art.artwork.artist', 5),
#  ('military.service.rank', 5),
#  ('soccer.player_loan.from', 5),
#  ('visual_art.artwork.date_completed', 5),
#  ('aviation.aircraft_model.range', 5),
#  ('soccer.player_transfer.selling_team', 5),
#  ('aviation.aircraft_model.wingspan', 5),
#  ('cvg.game_version.publisher', 5),
#  ('award.long_list_nomination.nominated_work', 5),
#  ('baseball.batting_statistics.at_bats', 5),
#  ('astronomy.orbital_relationship.semi_major_axis', 5),
#  ('law.inventor.inventions', 5),
#  ('biology.fossil_specimen.discovered_by', 5),
#  ('aviation.aircraft_model.maiden_flight', 5),
#  ('astronomy.asteroid.member_of_asteroid_family', 5),
#  ('sports.competitor_competition_relationship.country', 5),
#  ('soccer.player_match_participation.shirt_number', 5),
#  ('organization.organization.founder', 5),
#  ('theater.production.director', 5),
#  ('film.content_rating.film', 5),
#  ('organization.role.governors', 5),
#  ('sports.sports_team_roster.from', 5),
#  ('sports.multi_event_tournament.competitor_country_relationship', 5),
#  ('sports.competitor_country_relationship.sport', 5),
#  ('film.performance.film', 5),
#  ('chemistry.chemical_element.boiling_point', 5),
#  ('spaceflight.satellite.launch_date', 5),
#  ('astronomy.constellation.meteor_shower', 5),
#  ('award.nomination.ceremony', 5),
#  ('geography.waterfall.longest_height', 5),
#  ('sports.competitor_competition_relationship.rank', 5),
#  ('library.public_library.established_in', 5),
#  ('boats.ship_type.ship_class', 5),
#  ('american_football.game.game_passing_statistics', 5),
#  ('american_football.game_passing_statistics.player', 5),
#  ('award.honor.category', 5),
#  ('government.us_president.us_vice_president', 5),
#  ('zoos.zoo.num_animals', 5),
#  ('organization.committee.member', 5),
#  ('organization.committee_membership.member', 5),
#  ('organization.committee_membership.title', 5),
#  ('spaceflight.space_mission.destination', 5),
#  ('skiing.ski_area.number_of_runs', 5),
#  ('book.edition.publication_date', 5),
#  ('amusement_parks.park.opened', 5),
#  ('sports.pro_athlete.career_start', 5),
#  ('soccer.team_manager.team', 5),
#  ('architecture.structure.engineer', 5),
#  ('aviation.aircraft_model.retired', 5),
#  ('sports.championship_event.runner_up', 5),
#  ('award.honor.winning_work', 5),
#  ('music.composition.date_completed', 5),
#  ('geography.mountain.date_of_first_ascent', 5),
#  ('government.agency.date_founded', 5),
#  ('book.written_work.school_or_movement', 5),
#  ('spaceflight.space_program.completed', 5),
#  ('tv.program.spin_offs', 5),
#  ('biology.organism_classification.higher_classification', 5),
#  ('spaceflight.rocket.country_of_origin', 5),
#  ('book.newspaper.owner', 5),
#  ('film.performance.performance_type', 4),
#  ('government.political_party_tenure.to', 4),
#  ('biology.organism_classification.scientific_name', 4),
#  ('baseball.batting_statistics.hits', 4),
#  ('radio.radio_program.first_broadcast', 4),
#  ('geography.island.body_of_water', 4),
#  ('media_common.creative_work.audience', 4),
#  ('martial_arts.martial_art.origin', 4),
#  ('government.position_held.governmental_body', 4),
#  ('book.place_of_publication_period.place_of_publication', 4),
#  ('amusement_parks.ride.opened', 4),
#  ('business.operation.public', 4),
#  ('amusement_parks.ride.theme', 4),
#  ('award.award.category', 4),
#  ('ratings.rated_entity.review', 4),
#  ('sports.pro_sports_played.sport', 4),
#  ('book.written_work.date_written', 4),
#  ('film.set_designer.film', 4),
#  ('tv.actor.guest_roles', 4),
#  ('baseball.batting_statistics.rbis', 4),
#  ('amusement_parks.ride.duration', 4),
#  ('chemistry.chemical_compound.melting_point', 4),
#  ('geography.body_of_water.islands', 4),
#  ('martial_arts.martial_artist.instructor', 4),
#  ('baseball.batting_statistics.home_runs', 4),
#  ('meteorology.cloud.maximum_altitude_m', 4),
#  ('boats.ship_class.displacement_tons', 4),
#  ('people.romantic_relationship.romantic_relationship_type', 4),
#  ('astronomy.astronomical_discovery.discoverer', 4),
#  ('education.education.specialization', 4),
#  ('chemistry.chemical_compound.solubility', 4),
#  ('chemistry.solubility_relationship.solvent', 4),
#  ('chemistry.solubility_relationship.solubility', 4),
#  ('event.commercial_flight_action.flight_identifier', 4),
#  ('spaceflight.astronaut.space_mission', 4),
#  ('fictional_universe.object.object_destruction_method', 4),
#  ('film.director.film', 4),
#  ('fictional_universe.character.date_of_birth', 4),
#  ('fictional_universe.date_time.portrayed_in', 4),
#  ('fictional_universe.date_time.date_time', 4),
#  ('chemistry.chemical_compound.boiling_point', 4),
#  ('organization.board_membership.member', 4),
#  ('sports.team_season_record.losses', 4),
#  ('book.book.genre', 4),
#  ('tennis.player.number_of_grand_slam_titles', 4),
#  ('award.nomination.category', 4),
#  ('food.nutrition.nutrient', 4),
#  ('film.film.editor', 4),
#  ('skiing.ski_area.base_elevation', 4),
#  ('transportation.bridge.total_length', 4),
#  ('olympics.torch_relay.age', 4),
#  ('boxing.boxer.weight_division', 4),
#  ('baseball.player.hall_of_fame_induction', 4),
#  ('american_football.player.player_rushing_statistics', 4),
#  ('american_football.player_rushing_statistics.season', 4),
#  ('aviation.airport.operator', 4),
#  ('tv.regular_tv_appearance.series_season', 4),
#  ('tv.contestant_appearance.result', 4),
#  ('ratings.rated_entity.weighted_aggregate_rating', 4),
#  ('organization.membership.membership_organization', 4),
#  ('people.person.weight', 4),
#  ('american_football.player_receiving_statistics.receptions', 4),
#  ('american_football.player_receiving_statistics.season', 4),
#  ('conferences.academic_conference.final_version_due_date', 4),
#  ('music.concert.concert_set_list', 4),
#  ('media_common.subject.quotation', 4),
#  ('real_estate.house.number_of_bedrooms', 4),
#  ('event.event.parent_event', 4),
#  ('award.award.honor', 4),
#  ('tv.regular_tv_appearance.episode', 4),
#  ('baseball.batting_statistics.slugging_pct', 4),
#  ('soccer.team_management_tenure.team', 4),
#  ('tv.series_episode.guest_stars', 4),
#  ('astronomy.orbital_relationship.mean_orbital_speed', 4),
#  ('medicine.drug.drug_pregnancy_category', 4),
#  ('sports.golf_course.year_built', 4),
#  ('business.shopping_center.retail_floor_space_m_2', 4),
#  ('automotive.trim_level.model', 4),
#  ('astronomy.celestial_object.gravity', 4),
#  ('baseball.batting_statistics.sacrifice_hits', 4),
#  ('astronomy.constellation.galaxies_observed_in_constellation', 4),
#  ('sports.sports_team_coach_tenure.to', 4),
#  ('computer.processor.variants', 4),
#  ('projects.project_participation.to_date', 4),
#  ('meteorology.tropical_cyclone.highest_winds', 4),
#  ('zoos.animal_captivity.exhibit', 4),
#  ('spaceflight.space_program_sponsor.space_programs_sponsored', 4),
#  ('award.honor.ceremony', 4),
#  ('tv.crewmember.crew_gig', 4),
#  ('internet.website.launched', 4),
#  ('music.composition.place_of_first_performance', 4),
#  ('aviation.aircraft_model.length_meters', 4),
#  ('tv.contestant_appearance.team', 4),
#  ('geography.river.length', 4),
#  ('commerce.consumer_product.category', 3),
#  ('visual_art.artwork.medium', 3),
#  ('astronomy.astronomical_discovery.discovery_organization', 3),
#  ('internet.social_network_user.views', 3),
#  ('sports.team_season_record.wins', 3),
#  ('internet.social_network_user.following', 3),
#  ('transportation.road.length', 3),
#  ('rail.railway.opened', 3),
#  ('fictional_universe.character.creator', 3),
#  ('business.employer.employees_by_title', 3),
#  ('book.place_of_publication_period.from', 3),
#  ('organization.organization.focus_areas', 3),
#  ('location.sovereign.fips10_4', 3),
#  ('location.location.judicial_capital', 3),
#  ('comic_books.series.publisher', 3),
#  ('media_common.video_offer.pricing_model', 3),
#  ('sports.pro_sports_played.career_end', 3),
#  ('religion.religious_organization_leadership.start_date', 3),
#  ('award.competition.winner', 3),
#  ('people.person.relatives', 3),
#  ('people.kinship_relationship.kinship', 3),
#  ('people.kinship_relationship.object', 3),
#  ('book.editorial_tenure.title', 3),
#  ('real_estate.house.nearby_schools', 3),
#  ('spaceflight.rocket_manufacturer.rockets_manufactured', 3),
#  ('event.agent.address', 3),
#  ('organization.organization.location', 3),
#  ('book.edition.book', 3),
#  ('spaceflight.rocket.height_meters', 3),
#  ('film.genre_ranking.genre', 3),
#  ('visual_art.visual_artist.artworks', 3),
#  ('music.artist.active_end', 3),
#  ('biology.organism.children', 3),
#  ('opera.opera.language', 3),
#  ('media_common.content_rating.content', 3),
#  ('commerce.brand.brand_colors', 3),
#  ('commerce.brand_color.color', 3),
#  ('biology.organism_classification.lower_classification', 3),
#  ('geography.waterfall.height', 3),
#  ('military.conflict.commanders', 3),
#  ('military.command.combatant', 3),
#  ('military.command.commander', 3),
#  ('automotive.automotive_class.related', 3),
#  ('tv.program.review', 3),
#  ('baseball.batting_statistics.strikeouts', 3),
#  ('aviation.aviation_incident_aircraft_relationship.aircraft_model', 3),
#  ('award.ranking.year', 3),
#  ('book.written_work.read_work', 3),
#  ('people.person.nationality', 3),
#  ('astronomy.celestial_object.cosmological_distance', 3),
#  ('fictional_universe.work_of_fiction.setting', 3),
#  ('meteorology.cloud.appearance', 3),
#  ('music.artist.active_start', 3),
#  ('business.issue.stock_ticker_symbol', 3),
#  ('music.track.lyrics_website', 3),
#  ('sports.golf_course.length', 3),
#  ('finance.income_tax_filing_form.deadline', 3),
#  ('medicine.drug.canonical_brand', 3),
#  ('spaceflight.rocket_engine.dry_mass', 3),
#  ('conferences.academic_conference.notification_date', 3),
#  ('sports.sports_team_coach_tenure.from', 3),
#  ('amusement_parks.ride.ride_type', 3),
#  ('biology.gene.genomic_locus', 3),
#  ('application.software_version.support_url', 3),
#  ('soccer.player_transfer.fee', 3),
#  ('aviation.aircraft.aircraft_model', 3),
#  ('ratings.rated_entity.number_of_ratings', 3),
#  ('people.person.profession', 3),
#  ('music.artist.concert_tours', 3),
#  ('computer.computer.key_designers', 3),
#  ('location.dated_location.date_founded', 3),
#  ('food.food.nutrition', 3),
#  ('food.nutrition.nutrient_quantity', 3),
#  ('spaceflight.rocket_engine.height', 3),
#  ('media_common.video_offer.video_of', 3),
#  ('geography.lake.width', 3),
#  ('finance.currency.prefix_symbol', 3),
#  ('aviation.aircraft_model.cruise_speed', 3),
#  ('baseball.team.league', 3),
#  ('time.day_of_week.sequence_number', 3),
#  ('sports.team.sport', 3),
#  ('spaceflight.space_agency.astronauts', 3),
#  ('people.romantic_relationship.start_date', 3),
#  ('automotive.designer.automobiles_designed', 3),
#  ('real_estate.house.estimated_price', 3),
#  ('award.nomination.secondary_nominated_work', 3),
#  ('fictional_universe.character.character_powers', 3),
#  ('automotive.automotive_class.exterior_color', 3),
#  ('book.editorial_tenure.to', 3),
#  ('military.unit.armed_force', 3),
#  ('commerce.brand.consumer_product', 3),
#  ('music.artist.active_period', 3),
#  ('military.service.unit', 3),
#  ('award.category.category_of', 3),
#  ('event.disaster.fatalities', 3),
#  ('education.educational_institution.motto', 3),
#  ('sports.athlete.sports_statistics', 3),
#  ('book.edition.public_library_system', 3),
#  ('medicine.drug.drug_brand', 3),
#  ('cvg.game_version.platform', 3),
#  ('business.stock_ticker_symbol.ticker_symbol', 3),
#  ('education.school.school_district', 3),
#  ('opera.opera.date_written', 3),
#  ('organization.organization.child', 3),
#  ('medicine.physician.insurance_accepted', 3),
#  ('spaceflight.mission_destination.missions_sent_here', 3),
#  ('tv.contestant_appearance.partner', 3),
#  ('biology.animal.lifespan', 3),
#  ('book.author.series_written_or_contributed_to', 3),
#  ('sports.league.sport', 3),
#  ('boats.ship.length_overall', 3),
#  ('application.download_page.page_type', 3),
#  ('organization.role.leaders', 3),
#  ('games.game.introduced', 3),
#  ('music.concert_set_list.artist', 3),
#  ('baseball.team_stats.losses', 3),
#  ('tv.regular_personal_appearance.program', 3),
#  ('language.human_language.culture_code', 3),
#  ('film.series.director', 3),
#  ('book.written_work.next_in_series', 3),
#  ('food.recipe.recipe_ingredient', 3),
#  ('transportation.bridge.width', 3),
#  ('ratings.review.date', 3),
#  ('military.person.awards', 3),
#  ('geography.mountain.first_ascenders', 3),
#  ('film.film.costume_designer', 3),
#  ('american_football.team.conference', 3),
#  ('event.agent.social_network_user', 3),
#  ('tv.program.air_date_of_final_episode', 3),
#  ('law.court.judge', 3),
#  ('law.judicial_tenure.judge', 3),
#  ('baseball.batting_statistics.ibbs', 3),
#  ('zoos.zoo.opened', 3),
#  ('spaceflight.rocket.launch_site', 3),
#  ('military.combatant.military_conflicts', 3),
#  ('geography.mountaineer.first_ascents', 3),
#  ('film.film_song.film', 3),
#  ('film.film_song_relationship.film', 3),
#  ('film.film_song_relationship.performer', 3),
#  ('geography.river.discharge', 3),
#  ('tv.program.country_of_origin', 3),
#  ('law.attorney.business', 3),
#  ('cvg.platform.games_on_this_platform', 3),
#  ('award.competitor.competitions_won', 3),
#  ('film.appearance.type_of_appearance', 3),
#  ('visual_art.artwork.art_genre', 3),
#  ('application.software_version.install_size', 3),
#  ('religion.religious_organization_leadership.end_date', 3),
#  ('architecture.structure.opened', 3),
#  ('architecture.structure.structural_failure', 3),
#  ('architecture.structure_failure.failure_cause', 3),
#  ('architecture.structure_failure.causes_disaster', 3),
#  ('sports.athlete.position', 3),
#  ('tv.personality.tv_regular_appearances', 3),
#  ('book.edition.retail_price', 3),
#  ('organization.non_profit_organization.donate_url', 3),
#  ('computer.computer.introduced', 3),
#  ('opera.opera.date_of_first_performance', 3),
#  ('law.attorney.award', 3),
#  ('event.play_audio_action.album', 3),
#  ('spaceflight.bipropellant_rocket_engine.expansion_ratio', 3),
#  ('baseball.batting_statistics.bases_on_balls', 3),
#  ('chemistry.chemical_element.symbol', 3),
#  ('sports.competitor_country_relationship.tournament_event_competitor', 3),
#  ('spaceflight.rocket.diameter_meters', 3),
#  ('music.album.content_type', 3),
#  ('visual_art.visual_artist.associated_periods_or_movements', 3),
#  ('spaceflight.rocket_engine.isp_vacuum', 3),
#  ('visual_art.art_series.artist', 3),
#  ('tv.crew_gig.crew_role', 3),
#  ('tv.crew_gig.episode', 3),
#  ('baseball.team_stats.wins', 3),
#  ('transportation.road.formed', 3),
#  ('book.written_work.accelerated_reading_points', 3),
#  ('conferences.academic_conference.paper_submission_due_date', 3),
#  ('sports.team.fight_song', 3),
#  ('event.view_action.review', 3),
#  ('commerce.consumer_product.color', 3),
#  ('sports.sports_team_roster.number', 3),
#  ('book.author.institution', 3),
#  ('geography.body_of_water.bridge', 3),
#  ('music.concert_set_list.song', 3),
#  ('location.populated_place.postcode', 3),
#  ('biology.organism.parents', 3),
#  ('location.census_district.total_other_address', 3),
#  ('commerce.consumer_product.related_product', 3),
#  ('chemistry.chemical_classification.higher_classifications', 3),
#  ('biology.animal.height', 3),
#  ('sports.golf_course.holes', 3),
#  ('skiing.ski_area.top_elevation', 3),
#  ('music.composition.track', 2),
#  ('amusement_parks.ride.park', 2),
#  ('music.album.previous_album', 2),
#  ('cvg.game_version.computer_videogame', 2),
#  ('book.scholarly_work.prompt_publisher', 2),
#  ('people.deceased_person.cause_of_death', 2),
#  ('automotive.automotive_class.left_steering_diameter', 2),
#  ('baseball.batting_statistics.doubles', 2),
#  ('location.census_district.total_vacant_other', 2),
#  ('organization.organization.place_founded', 2),
#  ('application.software_version.version', 2),
#  ('music.instrument.family', 2),
#  ('biology.animal.mass', 2),
#  ('theater.production.date_opened', 2),
#  ('opera.opera.librettist', 2),
#  ('music.release_track.track_number', 2),
#  ('commerce.electronics_product.battery_average_time', 2),
#  ('spaceflight.rocket.number_of_stages', 2),
#  ('business.operation.place_of_incorporation', 2),
#  ('food.recipe_ingredient.quantity', 2),
#  ('book.magazine.place_of_publication', 2),
#  ('food.food.serving_size_structured', 2),
#  ('music.release.release_date', 2),
#  ('sports.sports_statistics.action_completion_category', 2),
#  ('commerce.consumer_product.weight', 2),
#  ('book.written_work.listen_work', 2),
#  ('medicine.physician.medical_specialty', 2),
#  ('ice_hockey.team.captain', 2),
#  ('local.entity.disabled', 2),
#  ('common.attribution.uri', 2),
#  ('boats.ship_class.ship_type', 2),
#  ('film.genre_ranking.ranking', 2),
#  ('religion.religious_organization_leadership.leader', 2),
#  ('architecture.lighthouse.automated', 2),
#  ('local.restaurant_offering.dish', 2),
#  ('book.edition.dewey_decimal_number', 2),
#  ('music.track.play_track', 2),
#  ('book.edition.isfdb_id', 2),
#  ('law.attorney.specialty', 2),
#  ('music.release.region', 2),
#  ('music.track.play_link', 2),
#  ('meteorology.tropical_cyclone.affected_area', 2),
#  ('visual_art.art_period_movement.associated_artwork', 2),
#  ('automotive.automotive_class.rear_track', 2),
#  ('award.presenting_organization.awards_presented', 2),
#  ('sports.tournament_event_competitor.events_competed_in', 2),
#  ('book.scholarly_work.doc_type', 2),
#  ('sports.competitor_competition_relationship.team', 2),
#  ('location.location.geobound', 2),
#  ('film.film.watch_film', 2),
#  ('soccer.player_transfer.date_transfer_was_agreed', 2),
#  ('music.track.date', 2),
#  ('transportation.bridge.longest_span', 2),
#  ('geography.mountain.prominence', 2),
#  ('common.webpage.uri', 2),
#  ('real_estate.house.nearby_home', 2),
#  ('people.person.email_address', 2),
#  ('spaceflight.bipropellant_rocket_engine.oxidizer_fuel_ratio', 2),
#  ('sports.athlete.games', 2),
#  ('architecture.structure.construction_started', 2),
#  ('american_football.player_passing_statistics.attempts', 2),
#  ('medicine.manufactured_drug_form.ndc_product_id', 2),
#  ('cvg.computer_videogame.genre', 2),
#  ('finance.currency.currency_code', 2),
#  ('finance.insurance_policy.issuer', 2),
#  ('martial_arts.martial_artist.martial_arts_students', 2),
#  ('sports.sports_statistics.event', 2),
#  ('business.employer.employment_tenure', 2),
#  ('soccer.player_match_participation.team', 2),
#  ('event.event.rank', 2),
#  ('astronomy.celestial_object.mean_density', 2),
#  ('medicine.physician.hospital_affiliation', 2),
#  ('sports.team_owner.teams_owned', 2),
#  ('film.film.trivia', 2),
#  ('commerce.electronics_product.battery_used', 2),
#  ('common.related_internal_concept.source', 2),
#  ('media_common.subject.creative_work', 2),
#  ('spaceflight.satellite.launch_vehicle', 2),
#  ('business.operation.revenue', 2),
#  ('sports.competitor_country_relationship.country', 2),
#  ('spaceflight.rocket_engine.isp_sea_level', 2),
#  ('geography.river.city', 2),
#  ('food.recipe.recipe_collection', 2),
#  ('award.nomination.nominated_work', 2),
#  ('local.restaurant.offering', 2),
#  ('business.product_line.consumer_product', 2),
#  ('business.job_posting.base_salary', 2),
#  ('tv.crew_role.tv_episodes', 2),
#  ('geography.glacier.length', 2),
#  ('tv.series_episode.producers', 2),
#  ('law.attorney.bing_category', 2),
#  ('music.album.genre', 2),
#  ('event.ticket.ticketed_event', 2),
#  ('tv.series_episode.season', 2),
#  ('film.performance.character_note', 2),
#  ('medicine.drug.drug_class', 2),
#  ('zoos.zoo.num_species', 2),
#  ('skiing.ski_area.skiable_area', 2),
#  ('computer.computer.graphical_processing_unit', 2),
#  ('travel.destination_monthly_climate.average_min_temp_c', 2),
#  ('tv.series_episode.previous_episode', 2),
#  ('book.edition.author_editor', 2),
#  ('internet.author.related_author', 2),
#  ('location.census_district.total_residential_address', 2),
#  ('business.operation.operating_income', 2),
#  ('tv.program.languages', 2),
#  ('games.game.playing_time_minutes', 2),
#  ('film.film.watch_preview', 2),
#  ('education.academic.field_of_study', 2),
#  ('event.commercial_flight_action.arrival', 2),
#  ('baseball.batting_statistics.runs', 2),
#  ('food.nutrition.food', 2),
#  ('tennis.player.year_turned_pro', 2),
#  ('food.recipe.preparation_time', 2),
#  ('american_football.player_rushing_statistics.touchdowns', 2),
#  ('music.release.length', 2),
#  ('automotive.automotive_class.wheelbase', 2),
#  ('commerce.consumer_product.recommended_uses', 2),
#  ('education.educational_institution.proficiency', 2),
#  ('book.edition.publisher', 2),
#  ('american_football.player_receiving_statistics.touchdowns', 2),
#  ('military.service.from_date', 2),
#  ('chemistry.chemical_compound.structure_smiles', 2),
#  ('book.edition.lcc', 2),
#  ('amusement_parks.ride.height', 2),
#  ('geography.body_of_water.mean_depth', 2),
#  ('soccer.team.current_roster', 2),
#  ('baseball.roster_position.position', 2),
#  ('soccer.roster_position.player', 2),
#  ('event.commercial_flight_action.departure', 2),
#  ('aviation.aircraft_designer.models_designed', 2),
#  ('food.recipe_ingredient.recipe', 2),
#  ('automotive.trim_level.option_package', 2),
#  ('statistics.population_group.population_growth_rate', 2),
#  ('time.time_zone.offset_from_uct', 2),
#  ('spaceflight.space_mission.space_program', 2),
#  ('american_football.game_passing_statistics.completions', 2),
#  ('soccer.roster_position.total_goals', 2),
#  ('business.stock_ticker_symbol.issue', 2),
#  ('computer.software.latest_release_date', 2),
#  ('food.recipe.recipe_author', 2),
#  ('organization.member.member_of', 2),
#  ('music.musician.instruments_played', 2),
#  ('conferences.academic_conference.abstract_due_date', 2),
#  ('local.entity.closing_date', 2),
#  ('broadcast.content.artist', 2),
#  ('sports.pro_athlete.debut', 2),
#  ('music.release.track_list', 2),
#  ('internet.social_network_user.social_network_key', 2),
#  ('geography.island.island_group', 2),
#  ('astronomy.star.star_system', 2),
#  ('baseball.batting_statistics.batting_average', 2),
#  ('common.related_external_concept.concept', 2),
#  ('organization.organization.phone_number', 2),
#  ('government.legislative_session.date_began', 2),
#  ('government.position_held.political_appointer', 2),
#  ('statistics.economic_group.labor_force', 2),
#  ('theater.play.date_of_first_performance', 2),
#  ('medicine.drug.drug_legal_status', 2),
#  ('commerce.electronics_product.hard_drive', 2),
#  ('architecture.skyscraper.height_with_antenna_spire_meters', 2),
#  ('commerce.consumer_product.product_model', 2),
#  ('sports.sports_statistics.strategy_category', 2),
#  ('music.concert_set_list.guest_artist', 2),
#  ('tv.appearance.appearance_type', 2),
#  ('event.event.venue', 2),
#  ('people.romantic_relationship.end_date', 2),
#  ('automotive.automotive_class.front_hiproom', 2),
#  ('tv.series_season.episodes', 2),
#  ('automotive.automotive_class.highway_fuel_economy_minimum', 2),
#  ('commerce.consumer_product.video', 2),
#  ('sports.team.roster', 2),
#  ('business.issue.issuer', 2),
#  ('film.film.genre_ranking', 2),
#  ('book.author.coauthor', 2),
#  ('business.stock_ticker_symbol.stock_exchange', 2),
#  ('award.category.nominees', 2),
#  ('government.political_party_tenure.from', 2),
#  ('music.track.contributions', 2),
#  ('real_estate.house.number_of_bathrooms', 2),
#  ('film.film.video_offer', 2),
#  ('spaceflight.rocket.maiden_flight', 2),
#  ('measurement_unit.dimensions.width_meters', 2),
#  ('location.census_district.average_days_business_vacant', 2),
#  ('commerce.electronics_product.ram_memory', 2),
#  ('media_common.quotation.subject', 2),
#  ('music.release.media_format', 2),
#  ('education.educational_institution.school_type', 2),
#  ('location.location.partially_containedby', 2),
#  ('zoos.animal_captivity.from', 2),
#  ('film.film.genre', 2),
#  ('location.location.served_by_airport', 2),
#  ('measurement_unit.dimensions.height_meters', 2),
#  ('visual_art.artwork.art_subject', 2),
#  ('military.service.to_date', 2),
#  ('rail.railway.length', 2),
#  ('spaceflight.rocket.mass', 2),
#  ('business.job_posting.location', 2),
#  ('aviation.aircraft_line.models_in_line', 2),
#  ('film.producer.film', 2),
#  ('american_football.game_passing_statistics.team', 2),
#  ('people.person.spouse', 2),
#  ('people.marriage.type', 2),
#  ('chemistry.chemical_element.van_der_waals_radius', 2),
#  ('organization.membership_organization.members', 2),
#  ('organization.membership.member', 2),
#  ('ratings.rated_entity.rating', 2),
#  ('meteorology.tropical_cyclone.dissipated', 2),
#  ('religion.religious_organization_leadership.jurisdiction', 2),
#  ('music.artist.origin', 2),
#  ('music.album.releases', 2),
#  ('local.restaurant.view_menu', 2),
#  ('people.person.member_of', 2),
#  ('automotive.engine.horsepower', 2),
#  ('event.view_action.book', 2),
#  ('award.ranked_item.ranking', 2),
#  ('medicine.manufactured_drug_form.label_section', 2),
#  ('architecture.building.occupancy', 2),
#  ('architecture.occupancy.building_occupant', 2),
#  ('architecture.occupancy.from', 2),
#  ('film.film.distribution', 2),
#  ('food.chef.restaurant', 2),
#  ('food.restaurant_chef_association.from_date', 2),
#  ('food.restaurant_chef_association.restaurant', 2),
#  ('book.edition.number_of_pages', 2),
#  ('film.festival.location', 2),
#  ('astronomy.asteroid.asteroid_group', 2),
#  ('astronomy.star.rotation', 2),
#  ('film.film.initial_release_date', 2),
#  ('local.entity.price_bracket', 2),
#  ('amusement_parks.park.closed', 2),
#  ('biology.organism.gender', 2),
#  ('travel.destination_monthly_climate.average_rainfall_mm', 2),
#  ('media_common.video_offer.source', 2),
#  ('transportation.bridge.clearance_below', 2),
#  ('real_estate.house.open_house', 2),
#  ('automotive.automotive_class.highway_fuel_economy_maximum', 2),
#  ('application.software_version.list_price', 2),
#  ('geography.river.basin_area', 2),
#  ('location.location.gnis_feature_id', 2),
#  ('tv.series_episode.program', 2),
#  ('real_estate.house.house_type', 2),
#  ('application.software_version.download_count', 2),
#  ('olympics.venue.olympic_games_used_in', 2),
#  ('book.written_work.word_count', 2),
#  ('music.composer.compositions', 2),
#  ('law.attorney.total_experience_year', 2),
#  ('religion.place_of_worship.type_of_place_of_worship', 2),
#  ('soccer.roster_position.from', 2),
#  ('religion.religious_organization_leadership.role', 2),
#  ('event.event.tag', 2),
#  ('fictional_universe.character.place_of_birth', 2),
#  ('geography.lake.shore_length', 2),
#  ('music.album.release_type', 2),
#  ('food.recipe.nutrition', 2),
#  ('broadcast.content.show_time', 2),
#  ('commerce.electronics_product.screen_resolution', 2),
#  ('film.subject.film', 2),
#  ('commerce.consumer_product.dimensions', 2),
#  ('government.political_party.politicians_in_this_party', 2),
#  ('meteorology.cloud.minimum_altitude', 2),
#  ('computer.software_developer.software', 2),
#  ('tv.series_episode.rating', 2),
#  ('music.release.release_type', 2),
#  ('astronomy.star_system.star', 2),
#  ('time.event.included_in_event', 2),
#  ('internet.social_network_user.source_social_network', 2),
#  ('transportation.trail.activity', 2),
#  ('boats.ship.ship_builder', 2),
#  ('media_common.creative_work.creation_date', 2),
#  ('transportation.bridge.bridge_type', 2),
#  ('food.recipe.suitable_for_diets', 2),
#  ('internet.social_network_user.social_network_url', 2),
#  ('spaceflight.satellite.dry_mass_kg', 2),
#  ('tv.actor.starring_roles', 2),
#  ('music.instrument.variation', 2),
#  ('broadcast.artist.content', 2),
#  ('physics.particle.spin', 2),
#  ('tv.producer.programs_produced', 2),
#  ('baseball.batting_statistics.gdp', 2),
#  ('real_estate.house.size', 2),
#  ('computer.computer.manufacturer_brand', 2),
#  ('event.play_audio_action.book', 2),
#  ('sports.tournament_event_competition.competitors', 2),
#  ('film.film.language', 2),
#  ('ice_hockey.team.division', 2),
#  ('boats.ship.place_built', 2),
#  ('aviation.airline.fleet_size', 2),
#  ('tv.producer.tv_episodes_produced', 2),
#  ('soccer.disciplinary_action.punishment', 2),
#  ('music.artist.contribution', 2),
#  ('medicine.drug_brand.active_ingredients', 2),
#  ('local.restaurant_offering.price', 2),
#  ('music.track.place', 2),
#  ('ratings.review.reviewer', 2),
#  ('internet.social_network_user.agent', 2),
#  ('music.artist.influences', 2),
#  ('event.agent.official_webpage', 2),
#  ('geography.body_of_water.depth', 2),
#  ('commerce.electronics_product.operating_system', 2),
#  ('architecture.structure.contractor', 2),
#  ('olympics.torch_relay.date', 2),
#  ('astronomy.celestial_object.magnitude', 2),
#  ('commerce.consumer_product.availability', 2),
#  ('law.judicial_tenure.to_date', 2),
#  ('amusement_parks.ride.max_g', 2),
#  ('location.location.address_line', 2),
#  ('american_football.game.game_rushing_statistics', 2),
#  ('american_football.game_rushing_statistics.carries', 2),
#  ('american_football.game_rushing_statistics.player', 2),
#  ('ratings.rating.aggregation_type', 2),
#  ('medicine.physician.new_patient_acceptance', 2),
#  ('tv.program.number_of_episodes', 2),
#  ('chemistry.chemical_element.ionization_energy', 2),
#  ('astronomy.comet.last_perihelion', 2),
#  ('people.person.ethnicity', 2),
#  ('people.person.sexual_orientation', 2),
#  ('people.sexual_orientation_phase.sexual_orientation', 2),
#  ('people.sexual_orientation_phase.start_date', 2),
#  ('baseball.batting_statistics.grand_slams', 2),
#  ('religion.place_of_worship.religion', 2),
#  ('chemistry.chemical_series.chemical_element', 2),
#  ('food.recipe.cooking_time', 2),
#  ('people.person.religion', 2),
#  ('music.artist.similar_artist', 2),
#  ('organization.organization.fax_number', 2),
#  ('protected_sites.listed_site.designation_as_natural_or_cultural_site', 2),
#  ('baseball.batting_statistics.player', 2),
#  ('automotive.automotive_class.front_track', 2),
#  ('astronomy.star_system_body.star_system', 2),
#  ('music.release.artist', 2),
#  ('education.education.educational_institution_name', 2),
#  ('organization.organization.acquired_by', 2),
#  ('business.acquisition.date', 2),
#  ('business.acquisition.acquiring_company', 2),
#  ('internet.social_network_user.likes', 2),
#  ('medicine.manufactured_drug_form.label_date', 2),
#  ('film.character.film', 2),
#  ('book.journal.place_of_publication', 2),
#  ('book.periodical.frequency_or_issues_per_year', 2),
#  ('book.periodical_frequency.to', 2),
#  ('book.periodical_frequency.frequency', 2),
#  ('film.genre.film', 2),
#  ('business.product_line.company_product_line_relationship', 2),
#  ('business.company_product_line_relationship.consumer_company', 2),
#  ('business.company_product_line_relationship.from_date', 2),
#  ('music.release.record_label', 2),
#  ('biology.gene_group.gene', 2),
#  ('food.dish.recipes', 2),
#  ('food.recipe.video', 2),
#  ('location.census_district.total_vacant_residence', 2),
#  ('spaceflight.satellite_manufacturer.spacecraft', 2),
#  ('ratings.rated_entity.video_offer', 2),
#  ('tv.producer_type.tv_producers_of_this_type', 2),
#  ('food.recipe_ingredient.ingredient', 2),
#  ('tv.series_season.program', 2),
#  ('music.album.contributor', 2),
#  ('astronomy.celestial_object.escape_velocity', 2),
#  ('basketball.coach.team', 2),
#  ('broadcast.broadcast.high_definition', 2),
#  ('commerce.brand_color.to_date', 2),
#  ('people.person.place_lived_location', 2),
#  ('award.ranked_list.ranking', 2),
#  ('computer.processor.processor_family', 2),
#  ('local.entity.make_reservation', 2),
#  ...]

# %% [raw]
# nx.draw(dev_category_tree, with_labels=True, font_weight='bold', node_size=1, font_size=7)

# %%
result_queue = queue.Queue()

# %%
dict_entity_lookup = pickle.load(open("DATA/dict_entity_lookup.pkl","rb"))
dict_entity_lookup= {ky:val for ky,val in dict_entity_lookup.items()}
print(len(dict_entity_lookup))
# Out:
# 21097

# %%
dict_entity_lookup["chuck_connors"]["itemListElement"][0]
# Out:
# {'@type': 'EntitySearchResult',
#  'result': {'@id': 'kg:/m/02hg53',
#   'name': 'Chuck Connors',
#   '@type': ['Thing', 'Person'],
#   'description': 'American actor',
#   'detailedDescription': {'articleBody': 'Kevin Joseph Aloysius "Chuck" Connors was an American actor, writer and professional basketball and baseball player. He is one of only 13 athletes in the history of American professional sports to have played both Major League Baseball and in the National Basketball Association. ',
#    'url': 'https://en.wikipedia.org/wiki/Chuck_Connors',
#    'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#   'image': {'contentUrl': 'http://t1.gstatic.com/images?q=tbn:ANd9GcQy1LqHRx9f0hthm-ZKa3_go2UQ3MSkdCUb3zNltqeMkEkoUufZ',
#    'url': 'https://commons.wikimedia.org/wiki/File:Chuck_Connors_Brooklyn_Dodgers.JPG'},
#   'url': 'http://www.ourchuckconnors.com/'},
#  'resultScore': 602.20166}

# %%
dev_jobs_to_do = [(1, x) for y in dev_data for x in y.get("parameters")]
train_jobs_to_do = [(1, x) for y in train_data for x in y.get("parameters")]
test_jobs_to_do = [(1, x) for y in test_data for x in y.get("parameters")]
all_jobs_to_do = [(x[0],x[1],ite) for ite, x in enumerate(train_jobs_to_do+dev_jobs_to_do+test_jobs_to_do)]

# %%
tally = 0
for x in all_jobs_to_do:
    if x[1] not in dict_entity_lookup:
        tally += 1
    else:
        if len(dict_entity_lookup[x[1]]["itemListElement"]) < 1:
            tally += 1
print(tally)
# Out:
# 4239

# %%
KB_tag_stats = defaultdict(int)
for x in dict_entity_lookup:
    for y in dict_entity_lookup[x]["itemListElement"]:
        try:
            for z in y["result"]["@type"]:
                KB_tag_stats[z] += 1
        except:
            print(y)
        break

# %%
dev_data[0]
# Out:
# {'question': 'the music composition sinfonia concertante for violin, viola & orchestra in e major, k. 320d/364: iii. presto is of which track?',
#  'logical_form': [('mso:music.composition.track',
#    'sinfonia_concertante_for_violin,_viola_&_orchestra_in_e_major,_k._320d/364:_iii._presto',
#    '',
#    '?x',
#    '?x')],
#  'parameters': ['sinfonia_concertante_for_violin,_viola_&_orchestra_in_e_major,_k._320d/364:_iii._presto'],
#  'question_type': 'single-relation'}

# %% [raw]
# api_key = "AIzaSyBqKgCNODOgDdPkhVCALFnF-ZVLodinPek" # ?
# query = 'running man'
# service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
# params = {
#     'query': query,
#     'limit': 10,
#     'indent': True,
#     'key': api_key,
# }
#
# url = service_url + '?' + urllib.parse.urlencode(params)
#
# while True:
#     try:
#         response = json.loads(urllib.request.urlopen(url).read())
#         break
#     except Exception as e:
#         if "429" in str(e):
#             print("sleep")
#             time.sleep(10)
# for element in response['itemListElement']:
#     print(element['result'], ' (' + str(element['resultScore']) + ')')

# %% [raw]
# dict_entity_lookup = {}
# tally = 0
# def req_split(base_url, argumnt, ent_id):
#     global tally, dict_entity_lookup
#     if argumnt in dict_entity_lookup:
#         return
#     print(argumnt)
#     params = {
#         'query': argumnt,
#         'limit': 10,
#         'indent': True,
#         'key': api_key,
#     }
#     url = service_url + '?' + urllib.parse.urlencode(params)
#
#     while True:
#         try:
#             resp = urllib.request.urlopen(url = service_url + '?' + urllib.parse.urlencode(params))
#             break
#         except Exception as e:
#             if "429" in str(e):
#                 print("sleep")
#                 time.sleep(30)
#
#     if resp.status == 200:
#         temp = resp.read() #return the url string if the server report OK
#     else:
#         temp = None
#     tally += 1
#     print(tally)
#     result_queue.put({argumnt:temp})
#
# dev_jobs_to_do = [(service_url, x) for y in dev_data for x in y.get("parameters")]
# train_jobs_to_do = [(service_url, x) for y in train_data for x in y.get("parameters")]
# test_jobs_to_do = [(service_url, x) for y in test_data for x in y.get("parameters")]
# all_jobs_to_do = [(x[0],x[1],ite) for ite, x in enumerate(train_jobs_to_do+dev_jobs_to_do+test_jobs_to_do)]

# %% [raw]
# begin_time = time.time()
# with Pool(150) as p:
#     entity_lookup = p.starmap(req_split, tqdm.tqdm(all_jobs_to_do[:]))
#     entity_lookup = [i for i in entity_lookup]
# end_time = time.time()
# print("finished in ", end_time-begin_time)
# entity_lookup = list(result_queue.queue)
# dict_entity_lookup = {ky:val for x in entity_lookup for ky,val in x.items()}

# %% [raw]
# with open("DATA/entity_lookup.pkl", 'wb') as fout:
#     pickle.dump(entity_lookup, fout)
# with open("DATA/dict_entity_lookup.pkl", 'wb') as fout:
#     pickle.dump(dict_entity_lookup, fout)
